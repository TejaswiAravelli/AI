# %% [markdown]
# <a href="https://colab.research.google.com/github/TejaswiAravelli/AI/blob/main/assg2prob2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![ai assg2 porb2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![ai assg2 prob2.2.jpeg](data:image/jpeg;base64,...)

# %%
import numpy as n
import math as m
x=n.random.uniform(-10,10)
y=n.random.uniform(-10,10)
eta=0.01
max=100
i=0
while i<max:
 x_slope=6*x
 y_slope=-5*m.exp(-y)
 x_step_length=-eta*x_slope
 y_step_length=-eta*y_slope
 x=x+x_step_length
 y=y+y_step_length
 i=i+1
min_value=3*m.pow(x,2)+5*m.exp(-y)+10
print("control variable x=",x)
print("control variable y=",y)
print("objective function=",min_value)
# Out:
# control variable x= 0.013252916801129784
# control variable y= 1.730723963982435
# objective function= 10.886307463864695

# %% [markdown]
# '
